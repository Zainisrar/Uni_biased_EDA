# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(6)
# Out:
#      PassengerId  Survived  Pclass  \
# 842          843         1       1
# 101          102         0       3
# 701          702         1       1
# 214          215         0       3
# 473          474         1       2
# 46            47         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 842                       Serepeca, Miss. Augusta  female  30.0      0      0
# 101              Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0      0
# 701              Silverthorne, Mr. Spencer Victor    male  35.0      0      0
# 214                           Kiernan, Mr. Philip    male   NaN      1      0
# 473  Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female  23.0      0      0
# 46                              Lennon, Mr. Denis    male   NaN      1      0
#
#               Ticket     Fare Cabin Embarked
# 842           113798  31.0000   NaN        C
# 101           349215   7.8958   NaN        S
# ...

# %% [markdown]
# 1st We Focus on Categorical Data

# %% [markdown]
# 1. Categorical Data

# %% [markdown]
# a. Countplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the overall figure size
plt.figure(figsize=(8,8))

# First subplot for the 'Survived' column
plt.subplot(2, 2, 1) # 2 rows, 2 columns, first plot
sns.countplot(x='Survived', data=df)
plt.ylabel('Number of People')
plt.title('Survival Distribution')

# Second subplot for the 'Pclass' column
plt.subplot(2, 2, 2) # 2 rows, 2 columns, second plot
sns.countplot(x='Pclass', data=df)
plt.ylabel('Number of People')
plt.title('PClass Distribution')

# Third subplot for the 'Embarked' column
plt.subplot(2, 2, 3) # 2 rows, 2 columns, third plot
sns.countplot(x='Embarked', data=df)
plt.ylabel('Number of People')
plt.title('Embarked Distribution')

# Fourth subplot for the 'Embarked' column (or another column)
plt.subplot(2, 2, 4) # 2 rows, 2 columns, fourth plot
sns.countplot(x='Sex', data=df)
plt.ylabel('Number of People')
plt.title('Sex Distribution')

# Display the plots
plt.tight_layout() # Adjust the layout to avoid overlap
plt.show()

# %% [markdown]
# b. PieChart

# %%
import matplotlib.pyplot as plt

# Define the label mappings
sex_labels = {0: 'Male', 1: 'Female'}
survived_labels = {0: 'Not Survived', 1: 'Survived'}
pclass_labels = {1: 'First Class', 2: 'Second Class', 3: 'Third Class'}
embarked_labels = {0: 'C', 1: 'Q', 2: 'S'} # Adjust this as per your mapping

# Set up the overall figure and subplots
fig, axes = plt.subplots(1, 4, figsize=(20,5)) # 1 row, 4 columns

# Plot 'Sex' pie chart
df["Sex"].replace(sex_labels).value_counts().plot(kind="pie", autopct="%.2f", ax=axes[0], title='Sex Distribution')

# Plot 'Survived' pie chart
df["Survived"].replace(survived_labels).value_counts().plot(kind="pie", autopct="%.2f", ax=axes[1], title='Survival Distribution')

# Plot 'Pclass' pie chart
df["Pclass"].replace(pclass_labels).value_counts().plot(kind="pie", autopct="%.2f", ax=axes[2], title='PClass Distribution')

# Plot 'Embarked' pie chart
df["Embarked"].replace(embarked_labels).value_counts().plot(kind="pie", autopct="%.2f", ax=axes[3], title='Embarked Distribution')

# Display the plots
plt.tight_layout() # Adjust the layout to avoid overlap
plt.show()

# %% [markdown]
# 2. Numerical Data

# %% [markdown]
# a. Histogram

# %%
plt.hist(df["Age"],bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# b. Distplot

# %%
sns.distplot(df["Age"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18388\2732350774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# c. Boxplot

# %%
plt.figure(figsize=(8, 6)) # Optional: Set the figure size
sns.boxplot(x=df["Fare"])
plt.title('Distribution of Fare') # Optional: Add a title
plt.xlabel('Fare') # Optional: Add an x-label
plt.show()

# %%
plt.figure(figsize=(8, 6)) # Optional: Set the figure size
sns.boxplot(x=df["Age"])
plt.title('Distribution of Fare') # Optional: Add a title
plt.xlabel('Fare') # Optional: Add an x-label
plt.show()
